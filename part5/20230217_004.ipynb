# 2018-06-15    2018
# 2018-06-14    2018
# 2018-06-12    2018
# 2018-06-11    2018
# 2018-06-08    2018
# 2018-06-07    2018
# 2018-06-05    2018
# 2018-06-04    2018
# 2018-06-01    2018

# %%
df_ym = df.loc['2018-07']
df_ym
# Out:
#                   Date  Close  Start   High    Low  Volume  Year  Month  Day  \
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977  2018      7    2
#
#            Date_yr
# new_Date
# 2018-07-02    2018

# %%
df_ym_cols = df.loc['2018-07','Start':'High']
df_ym_cols
# Out:
#             Start   High
# new_Date
# 2018-07-02  10850  10900

# %% [markdown]
# df_ymd = df['2018-07-02']
# print(df_ymd)

# %%
df_ymd_range = df['2018-06-20':'2018-06-25']
df_ymd_range
# Out:
#                   Date  Close  Start   High    Low  Volume  Year  Month  Day  \
# new_Date
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519  2018      6   25
# 2018-06-22  2018-06-22  11300  11250  11450  10750  134805  2018      6   22
# 2018-06-21  2018-06-21  11200  11350  11750  11200  133002  2018      6   21
# 2018-06-20  2018-06-20  11550  11200  11600  10900  308596  2018      6   20
#
#            Date_yr
# new_Date
# 2018-06-25    2018
# 2018-06-22    2018
# 2018-06-21    2018
# 2018-06-20    2018

# %%
df.loc['2018-06-20']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_scalar(self, value, allow_listlike, setitem, unbox)
#     623             try:
# --> 624                 value = self._scalar_from_string(value)
#     625             except ValueError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\timedeltas.py in _scalar_from_string(self, value)
#     339     def _scalar_from_string(self, value) -> Timedelta | NaTType:
# --> 340         return Timedelta(value)
#     341
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: only leading negative signs are allowed
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\timedeltas.py in get_loc(self, key, method, tolerance)
#     174         try:
# --> 175             key = self._data._validate_scalar(key, unbox=False)
#     176         except TypeError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_scalar(self, value, allow_listlike, setitem, unbox)
#     626                 msg = self._validation_error_message(value, allow_listlike)
# --> 627                 raise TypeError(msg) from err
#     628
#
# TypeError: value should be a 'Timedelta' or 'NaT'. Got 'str' instead.
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17008\1428868028.py in <module>
# ----> 1 df.loc['2018-06-20']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
#    1204         self._validate_key(key, axis)
# -> 1205         return self._get_label(key, axis=axis)
#    1206
#    1207     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1151     def _get_label(self, label, axis: int):
#    1152         # GH#5667 this will fail if the label is not present in the axis.
# -> 1153         return self.obj.xs(label, axis=axis)
#    1154
#    1155     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3862                     new_index = index[loc]
#    3863         else:
# -> 3864             loc = index.get_loc(key)
#    3865
#    3866             if isinstance(loc, np.ndarray):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\timedeltas.py in get_loc(self, key, method, tolerance)
#     175             key = self._data._validate_scalar(key, unbox=False)
#     176         except TypeError as err:
# --> 177             raise KeyError(key) from err
#     178
#     179         return Index.get_loc(self, key, method, tolerance)
#
# KeyError: '2018-06-20'

# %%
today=pd.to_datetime('2018-12-25')

# %%
df['time_delta']= today - df.index

# %%
df.set_index('time_delta', inplace=True)
df_180 = df['180 days':'189 days']
df_180
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: 180 days
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in _maybe_cast_slice_bound(self, label, side, kind)
#     314             try:
# --> 315                 parsed, reso = self._parse_with_reso(label)
#     316             except ValueError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in _parse_with_reso(self, label)
#     235             freq = getattr(self, "freqstr", getattr(self, "inferred_freq", None))
# --> 236         parsed, reso_str = parsing.parse_time_string(label, freq)
#     237         reso = Resolution.from_attrname(reso_str)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_time_string()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: 180 days
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17008\1654639609.py in <module>
#       1 df.set_index('time_delta', inplace=True)
# ----> 2 df_180 = df['180 days':'189 days']
#       3 df_180
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3475
#    3476         # Do we have a slicer (on rows)?
# -> 3477         indexer = convert_to_index_sliceable(self, key)
#    3478         if indexer is not None:
#    3479             if isinstance(indexer, np.ndarray):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2327     idx = obj.index
#    2328     if isinstance(key, slice):
# -> 2329         return idx._convert_slice_indexer(key, kind="getitem")
#    2330
#    2331     elif isinstance(key, str):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    4087             indexer = key
#    4088         else:
# -> 4089             indexer = self.slice_indexer(start, stop, step)
#    4090
#    4091         return indexer
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in slice_indexer(self, start, end, step, kind)
#     763         deprecation_mask = np.array(True)
#     764         if start is not None:
# --> 765             start_casted = self._maybe_cast_slice_bound(start, "left")
#     766             mask = start_casted <= self
#     767             deprecation_mask = start_casted == self
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in _maybe_cast_slice_bound(self, label, side, kind)
#     709     @doc(DatetimeTimedeltaMixin._maybe_cast_slice_bound)
#     710     def _maybe_cast_slice_bound(self, label, side: str, kind=lib.no_default):
# --> 711         label = super()._maybe_cast_slice_bound(label, side, kind=kind)
#     712         self._deprecate_mismatched_indexing(label)
#     713         return self._maybe_cast_for_get_loc(label)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in _maybe_cast_slice_bound(self, label, side, kind)
#     318                 # TDI -> 'unit abbreviation w/o a number'
#     319                 # PI -> string cannot be parsed as datetime-like
# --> 320                 raise self._invalid_indexer("slice", label) from err
#     321
#     322             lower, upper = self._parsed_string_to_bounds(reso, parsed)
#
# TypeError: cannot do slice indexing on DatetimeIndex with these indexers [180 days] of type str
